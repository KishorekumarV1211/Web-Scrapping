# %% [markdown]
# # Library Install

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
#
# ...

# %% [markdown]
# # Importing Libraries

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # Scraping Website

# %%
url="https://www.flipkart.com/laptops/pr?sid=6bo,b5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_18d48df0-64bf-4fe4-bd52-9d790fa5c09d_2_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_2.navigationCard.RICH_NAVIGATION_Electronics~Laptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y"

# %% [markdown]
# # Response

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# # Parsing

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
laptop=soup.select("._4rR01T")

# %%
laptop
# Out:
# [<div class="_4rR01T">HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GT...</div>,
#  <div class="_4rR01T">ASUS Celeron Dual Core - (4 GB/1 TB HDD/Windows 10 Home) X543MA-GQ1015T Laptop</div>,
#  <div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2629TU Thin and Light Laptop</div>,
#  <div class="_4rR01T">Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop</div>,
#  <div class="_4rR01T">acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 165...</div>,
#  <div class="_4rR01T">ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) X415EA-EB572WS T...</div>,
#  <div class="_4rR01T">DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Inspiron 3511 Thin and Lig...</div>,
# ...

# %%
laptop_list=[]

# %%
for item in laptop:
    laptop_list.append(item.text)
    laptop_list

# %%
laptop_list
# Out:
# ['HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce GT...',
#  'ASUS Celeron Dual Core - (4 GB/1 TB HDD/Windows 10 Home) X543MA-GQ1015T Laptop',
#  'HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2629TU Thin and Light Laptop',
#  'Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop',
#  'acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 165...',
#  'ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) X415EA-EB572WS T...',
#  'DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Inspiron 3511 Thin and Lig...',
#  'HP Pentium Quad Core - (8 GB/256 GB SSD/Windows 11 Home) 14s-dq3033tu Thin and Light Laptop',
#  'ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS Thin and L...',
# ...

# %%
price=soup.select('._1_WHN1')

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹60,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹23,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹50,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹49,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹45,340</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,144</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹35,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,440</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹44,440</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,340</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹42,940</div>,
#  <div class="_30jeq3 _1_WHN1">₹48,949</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,940</div>,
# ...

# %%
lap_price=[]

# %%
for item in price:
    lap_price.append(item.text)
    lap_price

# %%
lap_price
# Out:
# ['₹60,940',
#  '₹23,940',
#  '₹42,940',
#  '₹37,940',
#  '₹50,940',
#  '₹49,940',
#  '₹45,340',
#  '₹34,144',
#  '₹37,940',
#  '₹35,940',
#  '₹42,440',
#  '₹36,940',
#  '₹39,940',
#  '₹44,440',
#  '₹37,340',
#  '₹59,940',
#  '₹36,940',
#  '₹34,940',
#  '₹42,940',
#  '₹48,949',
#  '₹38,940',
#  '₹54,790',
#  '₹47,940',
#  '₹41,949']

# %%
processor=soup.select('div~ .MIXNux+ .row .rgWa7D:nth-child(2) , ._1AtVbE+ .col-12-12 .rgWa7D:nth-child(1)')

# %%
processor
# Out:
# [<li class="rgWa7D">Intel Celeron Dual Core Processor</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (10th Gen)</li>,
#  <li class="rgWa7D">Free upgrade to Windows 11 when available</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (11th Gen)</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li>,
#  <li class="rgWa7D">Intel Pentium Quad Core Processor</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (10th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 3 Dual Core Processor (3rd Gen)</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 3 Dual Core Processor</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li>,
#  <li class="rgWa7D">Intel Core i3 Processor (11th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 3 Dual Core Processor</li>,
# ...

# %%
processor_list=[]

# %%
for item in processor:
    processor_list.append(item.text)
    processor_list

# %%
processor_list
# Out:
# ['Intel Celeron Dual Core Processor',
#  'Intel Core i3 Processor (11th Gen)',
#  'Intel Core i3 Processor (10th Gen)',
#  'Free upgrade to Windows 11 when available',
#  'Intel Core i5 Processor (10th Gen)',
#  'Intel Core i5 Processor (11th Gen)',
#  'Intel Core i3 Processor (11th Gen)',
#  'Intel Pentium Quad Core Processor',
#  'Intel Core i3 Processor (10th Gen)',
#  'AMD Ryzen 3 Dual Core Processor (3rd Gen)',
#  'Intel Core i3 Processor (11th Gen)',
#  'AMD Ryzen 3 Dual Core Processor',
#  'Intel Core i3 Processor (11th Gen)',
#  'Intel Core i3 Processor (11th Gen)',
#  'AMD Ryzen 3 Dual Core Processor',
#  'Intel Core i5 Processor (10th Gen)',
#  'Intel Core i3 Processor (11th Gen)',
#  'Intel Core i3 Processor (11th Gen)',
#  'Intel Core i3 Processor (11th Gen)',
#  'AMD Ryzen 5 Hexa Core Processor',
#  'AMD Ryzen 3 Dual Core Processor',
#  'Intel Core i5 Processor (11th Gen)',
#  'AMD Ryzen 5 Hexa Core Processor',
#  'AMD Ryzen 3 Dual Core Processor']

# %%
OS=soup.select('.row:nth-child(2) .rgWa7D:nth-child(3) , div~ .MIXNux+ .row .rgWa7D:nth-child(4)')

# %%
OS
# Out:
# [<li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 10 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">Windows 10 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 10 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 10 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
#  <li class="rgWa7D">64 bit Windows 11 Operating System</li>,
# ...

# %%
OS_list=[]

# %%
for item in OS:
    OS_list.append(item.text)
    OS_list

# %%
OS_list
# Out:
# ['64 bit Windows 11 Operating System',
#  '64 bit Windows 10 Operating System',
#  '64 bit Windows 11 Operating System',
#  'Windows 10 Operating System',
#  '64 bit Windows 10 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 10 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 10 Operating System',
#  '64 bit Windows 11 Operating System',
#  'Windows 10 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 11 Operating System',
#  '64 bit Windows 10 Operating System']

# %%
SSD=soup.select('.rgWa7D:nth-child(4)')

# %%
SSD
# Out:
# [<li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">1 TB HDD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">64 bit Windows 10 Operating System</li>,
#  <li class="rgWa7D">1 TB HDD|256 GB SSD</li>,
#  <li class="rgWa7D">1 TB HDD|256 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">1 TB HDD|256 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">256 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">1 TB HDD|256 GB SSD</li>]

# %%
SSD_list=[]

# %%
for item in SSD:
    SSD_list.append(item.text)
    SSD_list

# %%
SSD_list
# Out:
# ['512 GB SSD',
#  '1 TB HDD',
#  '512 GB SSD',
#  '256 GB SSD',
#  '64 bit Windows 10 Operating System',
#  '1 TB HDD|256 GB SSD',
#  '1 TB HDD|256 GB SSD',
#  '256 GB SSD',
#  '512 GB SSD',
#  '256 GB SSD',
#  '512 GB SSD',
#  '512 GB SSD',
#  '256 GB SSD',
#  '1 TB HDD|256 GB SSD',
#  '256 GB SSD',
#  '512 GB SSD',
#  '256 GB SSD',
#  '256 GB SSD',
#  '512 GB SSD',
#  '512 GB SSD',
#  '256 GB SSD',
#  '512 GB SSD',
#  '512 GB SSD',
#  '1 TB HDD|256 GB SSD']

# %%
display=soup.select('._1AtVbE+ .col-12-12 .rgWa7D:nth-child(5) , div~ .MIXNux+ .row .rgWa7D:nth-child(6)')

# %%
display
# Out:
# [<li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">35.56 cm (14 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">35.56 cm (14 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">38.0 cm (14.96 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">35.56 cm (14 Inch) Display</li>,
# ...

# %%
display_list=[]

# %%
for item in display:
    display_list.append(item.text)
    display_list

# %%
display_list
# Out:
# ['39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 Inch) Display',
#  '512 GB SSD',
#  '39.62 cm (15.6 inch) Display',
#  '35.56 cm (14 inch) Display',
#  '39.62 cm (15.6 Inch) Display',
#  '35.56 cm (14 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 Inch) Display',
#  '38.0 cm (14.96 Inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '35.56 cm (14 Inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '35.56 cm (14 inch) Display',
#  '35.56 cm (14 inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 Inch) Display',
#  '39.62 cm (15.6 inch) Display',
#  '39.62 cm (15.6 inch) Display']

# %%
warranty=soup.select('.col-12-12:nth-child(8) .rgWa7D:nth-child(6) , .col-12-12:nth-child(15) .rgWa7D:nth-child(6) , .col-12-12:nth-child(16) .rgWa7D:nth-child(6) , .col-12-12:nth-child(18) .rgWa7D:nth-child(6) , .col-12-12:nth-child(24) .rgWa7D:nth-child(6) , .rgWa7D:nth-child(7)')

# %%
warranty
# Out:
# [<li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">2 Years Warranty</li>,
#  <li class="rgWa7D">Quick Access, Acer Care Center, Acer Product Registration, Acer Collection</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year International Travelers Warranty (ITW)</li>,
#  <li class="rgWa7D">1 Year Carry-In Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
#  <li class="rgWa7D">1 Year Onsite Warranty</li>,
# ...

# %%
warranty_list=[]

# %%
for item in warranty:
    warranty_list.append(item.text)
    warranty_list

# %%
warranty_list
# Out:
# ['1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '2 Years Warranty',
#  'Quick Access, Acer Care Center, Acer Product Registration, Acer Collection',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year International Travelers Warranty (ITW)',
#  '1 Year Carry-In Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty',
#  'Microsoft Office Home 2019 & Office 365, HP Documentation, HP SSRM, HP Smart',
#  '1 Year Onsite Warranty',
#  '1 Year Onsite Warranty']

# %% [markdown]
# # DATA FRAME

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
laptop=pd.DataFrame(laptop_list,columns=["LAPTOPS"])

# %%
laptop
# Out:
#                                               LAPTOPS
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...
# 14  DELL Inspiron Ryzen 3 Dual Core 3250U - (8 GB/...
# 15  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# ...

# %% [markdown]
# # Below syntax used to insert price,processor,os in row wise

# %%
laptop['PRICE'] = lap_price

# %%
laptop
# Out:
#                                               LAPTOPS    PRICE
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹60,940
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...  ₹23,940
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,940
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,940
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹50,940
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...  ₹49,940
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹45,340
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...  ₹34,144
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,940
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...  ₹35,940
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,440
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹36,940
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  ₹39,940
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹44,440
# ...

# %%
laptop['PROCESSOR'] = processor_list

# %%
laptop
# Out:
#                                               LAPTOPS    PRICE  \
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹60,940
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...  ₹23,940
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,940
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,940
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹50,940
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...  ₹49,940
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹45,340
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...  ₹34,144
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,940
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...  ₹35,940
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,440
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹36,940
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  ₹39,940
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹44,440
# ...

# %%
laptop['OPERATING SYSTEM'] = OS_list

# %%
laptop
# Out:
#                                               LAPTOPS    PRICE  \
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹60,940
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...  ₹23,940
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,940
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,940
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹50,940
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...  ₹49,940
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹45,340
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...  ₹34,144
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,940
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...  ₹35,940
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,440
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹36,940
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  ₹39,940
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹44,440
# ...

# %%
laptop['SSD'] = SSD_list

# %%
laptop
# Out:
#                                               LAPTOPS    PRICE  \
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹60,940
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...  ₹23,940
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,940
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,940
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹50,940
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...  ₹49,940
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹45,340
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...  ₹34,144
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,940
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...  ₹35,940
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,440
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹36,940
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  ₹39,940
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹44,440
# ...

# %%
laptop['DISPLAY'] = display_list

# %%
laptop
# Out:
#                                               LAPTOPS    PRICE  \
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹60,940
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...  ₹23,940
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,940
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,940
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹50,940
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...  ₹49,940
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹45,340
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...  ₹34,144
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,940
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...  ₹35,940
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,440
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹36,940
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  ₹39,940
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹44,440
# ...

# %%
laptop['WARRANTY'] = warranty_list

# %%
laptop
# Out:
#                                               LAPTOPS    PRICE  \
# 0   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...  ₹60,940
# 1   ASUS Celeron Dual Core - (4 GB/1 TB HDD/Window...  ₹23,940
# 2   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,940
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...  ₹37,940
# 4   acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB ...  ₹50,940
# 5   ASUS VivoBook 14 (2021) Core i5 11th Gen - (8 ...  ₹49,940
# 6   DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹45,340
# 7   HP Pentium Quad Core - (8 GB/256 GB SSD/Window...  ₹34,144
# 8   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...  ₹37,940
# 9   ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/2...  ₹35,940
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹42,440
# 11  acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/...  ₹36,940
# 12  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...  ₹39,940
# 13  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...  ₹44,440
# ...

# %%
laptop.to_csv('laptop.csv')
